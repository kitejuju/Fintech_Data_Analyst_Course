# %% [markdown]
# # 분석 준비

# %%
import pandas as pd
import numpy as np
import os
import re

# 시각화를 위한 패키지
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False # '-' 깨짐 방지

import matplotlib.pyplot as plt
plt.rcParams["font.family"] = 'Malgun Gothic' # 한글 깨짐 방지
plt.rcParams["font.size"] = 12
plt.rcParams["figure.figsize"] = (8, 6)
# %matplotlib inline

import seaborn as sns
# sns.set()

# 결측값 시각화를 위한 패키지
import missingno as msno

# %%
os.getcwd()
# Out:
# 'C:\\workspace\\Python\\4-2) 핀테크 교육\\Final Project'

# %%
os.chdir(r".\data")
os.getcwd()
# Out:
# 'C:\\workspace\\Python\\4-2) 핀테크 교육\\Final Project\\data'

# %% [markdown]
# # Load data

# %%
rawdata = pd.read_csv("9.2.1 소비자동향조사(한국은행_전국).csv", encoding='CP949')

print(rawdata.shape)
# Out:
# (82, 62)

# %%
rawdata.head()
# Out:
#                 항목명1     항목명2  2015년 1월  2015년 2월  2015년 3월  2015년 4월  \
# 0  경기종합지수(동행지수순환변동치)       전체      99.9     100.2     100.1     100.1
# 1          현재경기판단CSI       전체      74.0      71.0      72.0      77.0
# 2          현재경기판단CSI       남자      75.0      71.0      73.0      78.0
# 3          현재경기판단CSI       여자      72.0      71.0      71.0      74.0
# 4          현재경기판단CSI    40세미만      74.0      71.0      71.0      73.0
#
#    2015년 5월  2015년 6월  2015년 7월  2015년 8월  ...  2019년 3월  2019년 4월  2019년 5월  \
# 0      99.7      99.5      99.5      99.8  ...      99.2      99.2      99.5
# 1      79.0      65.0      63.0      71.0  ...      70.0      74.0      69.0
# 2      80.0      65.0      63.0      71.0  ...      69.0      73.0      68.0
# 3      79.0      64.0      64.0      72.0  ...      72.0      76.0      75.0
# 4      77.0      64.0      66.0      68.0  ...      79.0      85.0      79.0
#
#    2019년 6월  2019년 7월  2019년 8월  2019년 9월  2019년 10월  2019년 11월  2019년 12월
# 0      99.4      99.3      99.5      99.5       99.4       99.3        NaN
# 1      69.0      67.0      63.0      68.0       72.0       73.0       74.0
# 2      67.0      66.0      61.0      67.0       71.0       72.0       73.0
# 3      75.0      74.0      69.0      73.0       77.0       78.0       78.0
# 4      79.0      78.0      71.0      79.0       81.0       83.0       82.0
#
# [5 rows x 62 columns]

# %%
rawdata.tail()
# Out:
#                      항목명1      항목명2  2015년 1월  2015년 2월  2015년 3월  2015년 4월  \
# 77      교통비 및 통신비 지출전망CSI    40-50세     115.0     117.0     115.0     114.0
# 78      교통비 및 통신비 지출전망CSI    50-60세     115.0     115.0     113.0     115.0
# 79      교통비 및 통신비 지출전망CSI    60-70세     107.0     106.0     105.0     110.0
# 80      교통비 및 통신비 지출전망CSI     70세이상     104.0     110.0     106.0     111.0
# 81                소비자심리지수        전체     102.1     102.8     100.9     103.7
#
#     2015년 5월  2015년 6월  2015년 7월  2015년 8월  ...  2019년 3월  2019년 4월  2019년 5월  \
# 77     112.0     113.0     115.0     112.0  ...     111.0     111.0     112.0
# 78     114.0     114.0     118.0     113.0  ...     109.0     110.0     112.0
# 79     107.0     110.0     109.0     110.0  ...     105.0     105.0     108.0
# 80     107.0     108.0     107.0     107.0  ...     106.0     108.0     113.0
# 81     105.0      97.7      99.8     101.1  ...      99.8     101.7      97.9
#
#     2019년 6월  2019년 7월  2019년 8월  2019년 9월  2019년 10월  2019년 11월  2019년 12월
# 77     109.0     107.0     107.0     109.0      108.0      110.0      110.0
# 78     109.0     106.0     106.0     106.0      108.0      108.0      107.0
# 79     107.0     103.0     100.0     104.0      103.0      103.0      104.0
# 80     109.0     109.0     107.0     106.0      106.0      105.0      108.0
# 81      97.6      95.9      92.4      97.0       98.6      101.0      100.5
#
# [5 rows x 62 columns]

# %% [markdown]
# # EDA

# %%
df = rawdata.copy()
df.head()
# Out:
#                 항목명1     항목명2  2015년 1월  2015년 2월  2015년 3월  2015년 4월  \
# 0  경기종합지수(동행지수순환변동치)       전체      99.9     100.2     100.1     100.1
# 1          현재경기판단CSI       전체      74.0      71.0      72.0      77.0
# 2          현재경기판단CSI       남자      75.0      71.0      73.0      78.0
# 3          현재경기판단CSI       여자      72.0      71.0      71.0      74.0
# 4          현재경기판단CSI    40세미만      74.0      71.0      71.0      73.0
#
#    2015년 5월  2015년 6월  2015년 7월  2015년 8월  ...  2019년 3월  2019년 4월  2019년 5월  \
# 0      99.7      99.5      99.5      99.8  ...      99.2      99.2      99.5
# 1      79.0      65.0      63.0      71.0  ...      70.0      74.0      69.0
# 2      80.0      65.0      63.0      71.0  ...      69.0      73.0      68.0
# 3      79.0      64.0      64.0      72.0  ...      72.0      76.0      75.0
# 4      77.0      64.0      66.0      68.0  ...      79.0      85.0      79.0
#
#    2019년 6월  2019년 7월  2019년 8월  2019년 9월  2019년 10월  2019년 11월  2019년 12월
# 0      99.4      99.3      99.5      99.5       99.4       99.3        NaN
# 1      69.0      67.0      63.0      68.0       72.0       73.0       74.0
# 2      67.0      66.0      61.0      67.0       71.0       72.0       73.0
# 3      75.0      74.0      69.0      73.0       77.0       78.0       78.0
# 4      79.0      78.0      71.0      79.0       81.0       83.0       82.0
#
# [5 rows x 62 columns]

# %% [markdown]
# ## missing value

# %%
df.isnull().sum()
# Out:
# 항목명1         0
# 항목명2         0
# 2015년 1월     0
# 2015년 2월     0
# 2015년 3월     0
#             ..
# 2019년 8월     0
# 2019년 9월     0
# 2019년 10월    0
# 2019년 11월    0
# 2019년 12월    1
# Length: 62, dtype: int64

# %%
msno.matrix(df, figsize=(20,6))

# %%
# 경기종합지수 결측열 제거
df = df.drop(['2019년 12월'], axis=1)

# %% [markdown]
# ## 공백 제거

# %%
# 행이름, 데이터 공백 제거
df['항목명1'] = list(map(lambda x: x.strip(), df['항목명1'].values))
df['항목명2'] = list(map(lambda x: x.strip(), df['항목명2'].values))

# %% [markdown]
# # 경기종합지수 분석(불황시기 탐색)

# %%
df_eco = df.T
df_eco.columns = df_eco.loc['항목명1']
df_eco = df_eco.drop(['항목명1', '항목명2'], axis=0)
df_eco = df_eco[['경기종합지수(동행지수순환변동치)', '소비자심리지수']]
df_eco.head()
# Out:
# 항목명1     경기종합지수(동행지수순환변동치) 소비자심리지수
# 2015년 1월              99.9   102.1
# 2015년 2월             100.2   102.8
# 2015년 3월             100.1   100.9
# 2015년 4월             100.1   103.7
# 2015년 5월              99.7     105

# %% [markdown]
# ## MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df_eco['경기종합지수(동행지수순환변동치)'] = scaler.fit_transform(np.array(df_eco['경기종합지수(동행지수순환변동치)']).reshape(-1, 1))
df_eco['소비자심리지수'] = scaler.fit_transform(np.array(df_eco['소비자심리지수']).reshape(-1, 1))

# %%
df_eco.head()
# Out:
# 항목명1      경기종합지수(동행지수순환변동치)   소비자심리지수
# 2015년 1월           0.466667  0.487562
# 2015년 2월           0.666667  0.522388
# 2015년 3월           0.600000  0.427861
# 2015년 4월           0.600000  0.567164
# 2015년 5월           0.333333  0.631841

# %%
df_eco.plot(figsize=(20, 10))

# %% [markdown]
# ## 2개월 이동평균

# %%
ma2 = df_eco['경기종합지수(동행지수순환변동치)'].rolling(window=2).mean()
df_eco.insert(len(df_eco.columns), "경기종합지수_MA2", ma2)

ma22 = df_eco['소비자심리지수'].rolling(window=2).mean()
df_eco.insert(len(df_eco.columns), "소비자심리지수_MA2", ma22)

# %%
df_eco[['경기종합지수_MA2', '소비자심리지수_MA2']].plot(figsize=(20, 10))

# %% [markdown]
# ## 3개월 이동평균

# %%
ma3 = df_eco['경기종합지수(동행지수순환변동치)'].rolling(window=3).mean()
df_eco.insert(len(df_eco.columns), "경기종합지수_MA3", ma3)

ma33 = df_eco['소비자심리지수'].rolling(window=3).mean()
df_eco.insert(len(df_eco.columns), "소비자심리지수_MA3", ma33)

# %%
df_eco[['경기종합지수_MA3', '소비자심리지수_MA3']].plot(figsize=(20, 10))

# %% [markdown]
# ## 6개월 이동평균

# %%
ma6 = df_eco['경기종합지수(동행지수순환변동치)'].rolling(window=6).mean()
df_eco.insert(len(df_eco.columns), "경기종합지수_MA6", ma6)

ma66 = df_eco['소비자심리지수'].rolling(window=6).mean()
df_eco.insert(len(df_eco.columns), "소비자심리지수_MA6", ma66)

# %%
df_eco[['경기종합지수_MA6', '소비자심리지수_MA6']].plot(figsize=(20, 10))

# %% [markdown]
# -> 분석 기간 : 2017/11 - 2018/05

# %% [markdown]
# # Feature Engineering

# %%
df.head()
# Out:
#                 항목명1   항목명2  2015년 1월  2015년 2월  2015년 3월  2015년 4월  2015년 5월  \
# 0  경기종합지수(동행지수순환변동치)     전체      99.9     100.2     100.1     100.1      99.7
# 1          현재경기판단CSI     전체      74.0      71.0      72.0      77.0      79.0
# 2          현재경기판단CSI     남자      75.0      71.0      73.0      78.0      80.0
# 3          현재경기판단CSI     여자      72.0      71.0      71.0      74.0      79.0
# 4          현재경기판단CSI  40세미만      74.0      71.0      71.0      73.0      77.0
#
#    2015년 6월  2015년 7월  2015년 8월  ...  2019년 2월  2019년 3월  2019년 4월  2019년 5월  \
# 0      99.5      99.5      99.8  ...      99.3      99.2      99.2      99.5
# 1      65.0      63.0      71.0  ...      70.0      70.0      74.0      69.0
# 2      65.0      63.0      71.0  ...      70.0      69.0      73.0      68.0
# 3      64.0      64.0      72.0  ...      71.0      72.0      76.0      75.0
# 4      64.0      66.0      68.0  ...      79.0      79.0      85.0      79.0
#
#    2019년 6월  2019년 7월  2019년 8월  2019년 9월  2019년 10월  2019년 11월
# 0      99.4      99.3      99.5      99.5       99.4       99.3
# 1      69.0      67.0      63.0      68.0       72.0       73.0
# 2      67.0      66.0      61.0      67.0       71.0       72.0
# 3      75.0      74.0      69.0      73.0       77.0       78.0
# 4      79.0      78.0      71.0      79.0       81.0       83.0
#
# [5 rows x 61 columns]

# %%
df = df[['항목명1', '항목명2', 
         '2017년 7월', '2017년 8월', '2017년 9월', '2017년 10월', '2017년 11월', '2017년 12월', 
         '2018년 1월', '2018년 2월', '2018년 3월', '2018년 4월', '2018년 5월', '2017년 6월', 
         '2018년 7월', '2018년 8월', '2018년 9월', '2018년 10월', '2018년 11월', '2018년 12월']]

# %%
df.head()
# Out:
#                 항목명1   항목명2  2017년 7월  2017년 8월  2017년 9월  2017년 10월  \
# 0  경기종합지수(동행지수순환변동치)     전체     100.5     100.4     100.4      100.2
# 1          현재경기판단CSI     전체      96.0      93.0      87.0       91.0
# 2          현재경기판단CSI     남자      95.0      93.0      86.0       91.0
# 3          현재경기판단CSI     여자      99.0      94.0      92.0       94.0
# 4          현재경기판단CSI  40세미만     101.0      97.0      94.0       96.0
#
#    2017년 11월  2017년 12월  2018년 1월  2018년 2월  2018년 3월  2018년 4월  2018년 5월  \
# 0      100.2       99.8      99.8      99.8      99.8      99.7      99.7
# 1       98.0       95.0      90.0      89.0      87.0      86.0      89.0
# 2       98.0       95.0      89.0      88.0      87.0      86.0      88.0
# 3       99.0       97.0      92.0      92.0      89.0      90.0      94.0
# 4      104.0       98.0      93.0      94.0      93.0      95.0      97.0
#
#    2017년 6월  2018년 7월  2018년 8월  2018년 9월  2018년 10월  2018년 11월  2018년 12월
# 0     100.6     100.6     100.5     100.2      100.1      100.0       99.9
# 1      93.0      77.0      70.0      64.0       67.0       62.0       62.0
# 2      92.0      76.0      68.0      64.0       67.0       61.0       62.0
# 3      97.0      83.0      76.0      64.0       69.0       65.0       65.0
# 4      99.0      86.0      77.0      74.0       74.0       70.0       72.0

# %% [markdown]
# # 항목별 지출 추이

# %% [markdown]
# ## 전체

# %%
df_all = df[df['항목명2'] == '전체']
df_all = df_all.T
df_all.columns = df_all.loc['항목명1']
df_all = df_all.drop(['항목명1', '항목명2'], axis=0)
df_all['경기_소비자_중앙값'] = (df_all['경기종합지수(동행지수순환변동치)'] + df_all['소비자심리지수']) / 2

for c in df_all.columns:
    df_all[c] = df_all[c].astype('float')
    
df_all.head()
# Out:
# 항목명1       경기종합지수(동행지수순환변동치)  현재경기판단CSI  소비지출전망CSI  내구재 지출전망CSI  의류비 지출전망CSI  \
# 2017년 7월               100.5       96.0      108.0         97.0        101.0
# 2017년 8월               100.4       93.0      109.0         96.0        100.0
# 2017년 9월               100.4       87.0      107.0         96.0        103.0
# 2017년 10월              100.2       91.0      108.0         96.0        103.0
# 2017년 11월              100.2       98.0      109.0         97.0        103.0
#
# 항목명1       외식비 지출전망CSI  여행비 지출전망CSI  교육비 지출전망CSI  의료·보건비 지출전망CSI  \
# 2017년 7월          94.0         99.0        106.0           111.0
# 2017년 8월          95.0         95.0        107.0           112.0
# 2017년 9월          94.0         95.0        106.0           112.0
# 2017년 10월         93.0         95.0        107.0           112.0
# 2017년 11월         94.0         97.0        108.0           112.0
#
# 항목명1       교양·오락·문화생활비 지출전망CSI  교통비 및 통신비 지출전망CSI  소비자심리지수  경기_소비자_중앙값
# 2017년 7월                  91.0              108.0    111.3       105.9
# 2017년 8월                  92.0              108.0    110.0       105.2
# 2017년 9월                  90.0              109.0    107.6       104.0
# 2017년 10월                 91.0              109.0    109.2       104.7
# 2017년 11월                 93.0              109.0    112.4       106.3

# %%
corr_all = df_all.corrwith(df_all.경기_소비자_중앙값, method='pearson') 
corr_all = pd.DataFrame(corr_all, columns=['상관계수']) 
corr_all = corr_all.sort_values(by='상관계수')
corr_all
# Out:
#                          상관계수
# 항목명1
# 의료·보건비 지출전망CSI      -0.647909
# 경기종합지수(동행지수순환변동치)    0.014498
# 소비지출전망CSI            0.019424
# 교양·오락·문화생활비 지출전망CSI  0.318635
# 교통비 및 통신비 지출전망CSI    0.324965
# 내구재 지출전망CSI          0.681692
# 외식비 지출전망CSI          0.729150
# 교육비 지출전망CSI          0.799966
# 의류비 지출전망CSI          0.818391
# 여행비 지출전망CSI          0.867192
# 현재경기판단CSI            0.984068
# 소비자심리지수              0.998346
# 경기_소비자_중앙값           1.000000

# %%
plt.figure(figsize = (5, 5))
sns.heatmap(corr_all, annot=True, fmt='.2f', linewidths=.5, cmap='Reds')
plt.title('Heatmap')
plt.show()

# %% [markdown]
# ## 남자

# %%
df_man = df[df['항목명2'] == '남자']
df_man = pd.concat([df.iloc[[0]], df.iloc[[81]], df_man])
df_man = df_man.T
df_man.columns = df_man.loc['항목명1']
df_man = df_man.drop(['항목명1', '항목명2'], axis=0)
df_man['경기_소비자_중앙값'] = (df_man['경기종합지수(동행지수순환변동치)'] + df_man['소비자심리지수']) / 2

for c in df_man.columns:
    df_man[c] = df_man[c].astype('float')

# %%
corr_man = df_man.corrwith(df_man.경기_소비자_중앙값, method='pearson') 
corr_man = pd.DataFrame(corr_man, columns=['상관계수']) 
corr_man = corr_man.sort_values(by='상관계수')

# %%
plt.figure(figsize = (5, 5))
sns.heatmap(corr_man, annot=True, fmt='.2f', linewidths=.5, cmap='Reds')
plt.title('Heatmap')
plt.show()

# %% [markdown]
# ## 여자

# %%
df_woman = df[df['항목명2'] == '여자']
df_woman = pd.concat([df.iloc[[0]], df.iloc[[81]], df_woman])
df_woman = df_woman.T
df_woman.columns = df_woman.loc['항목명1']
df_woman = df_woman.drop(['항목명1', '항목명2'], axis=0)
df_woman['경기_소비자_중앙값'] = (df_woman['경기종합지수(동행지수순환변동치)'] + df_woman['소비자심리지수']) / 2

for c in df_woman.columns:
    df_woman[c] = df_woman[c].astype('float')

# %%
corr_woman = df_woman.corrwith(df_woman.경기_소비자_중앙값, method='pearson') 
corr_woman = pd.DataFrame(corr_woman, columns=['상관계수']) 
corr_woman = corr_woman.sort_values(by='상관계수')

# %%
plt.figure(figsize = (5, 5))
sns.heatmap(corr_woman, annot=True, fmt='.2f', linewidths=.5, cmap='Reds')
plt.title('Heatmap')
plt.show()

# %% [markdown]
# ## 40세 미만

# %%
df_40 = df[df['항목명2'] == '40세미만']
df_40 = pd.concat([df.iloc[[0]], df.iloc[[81]], df_40])
df_40 = df_40.T
df_40.columns = df_40.loc['항목명1']
df_40 = df_40.drop(['항목명1', '항목명2'], axis=0)
df_40['경기_소비자_중앙값'] = (df_40['경기종합지수(동행지수순환변동치)'] + df_40['소비자심리지수']) / 2

for c in df_40.columns:
    df_40[c] = df_40[c].astype('float')

# %%
corr_40 = df_40.corrwith(df_40.경기_소비자_중앙값, method='pearson') 
corr_40 = pd.DataFrame(corr_40, columns=['상관계수']) 
corr_40 = corr_40.sort_values(by='상관계수')

# %%
plt.figure(figsize = (5, 5))
sns.heatmap(corr_40, annot=True, fmt='.2f', linewidths=.5, cmap='Reds')
plt.title('Heatmap')
plt.show()

# %% [markdown]
# ## 40-50세

# %%
df_450 = df[df['항목명2'] == '40-50세']
df_450 = pd.concat([df.iloc[[0]], df.iloc[[81]], df_450])
df_450 = df_450.T
df_450.columns = df_450.loc['항목명1']
df_450 = df_450.drop(['항목명1', '항목명2'], axis=0)
df_450['경기_소비자_중앙값'] = (df_450['경기종합지수(동행지수순환변동치)'] + df_450['소비자심리지수']) / 2

for c in df_450.columns:
    df_450[c] = df_450[c].astype('float')

# %%
corr_450 = df_450.corrwith(df_450.경기_소비자_중앙값, method='pearson') 
corr_450 = pd.DataFrame(corr_450, columns=['상관계수']) 
corr_450 = corr_450.sort_values(by='상관계수')

# %%
plt.figure(figsize = (5, 5))
sns.heatmap(corr_450, annot=True, fmt='.2f', linewidths=.5, cmap='Reds')
plt.title('Heatmap')
plt.show()

# %% [markdown]
# ## 50-60세

# %%
df_560 = df[df['항목명2'] == '50-60세']
df_560 = pd.concat([df.iloc[[0]], df.iloc[[81]], df_560])
df_560 = df_560.T
df_560.columns = df_560.loc['항목명1']
df_560 = df_560.drop(['항목명1', '항목명2'], axis=0)
df_560['경기_소비자_중앙값'] = (df_560['경기종합지수(동행지수순환변동치)'] + df_560['소비자심리지수']) / 2

for c in df_560.columns:
    df_560[c] = df_560[c].astype('float')

# %%
corr_560 = df_560.corrwith(df_560.경기_소비자_중앙값, method='pearson') 
corr_560 = pd.DataFrame(corr_560, columns=['상관계수']) 
corr_560 = corr_560.sort_values(by='상관계수')

# %%
plt.figure(figsize = (5, 5))
sns.heatmap(corr_560, annot=True, fmt='.2f', linewidths=.5, cmap='Reds')
plt.title('Heatmap')
plt.show()

# %% [markdown]
# ## 60-70세

# %%
df_670 = df[df['항목명2'] == '60-70세']
df_670 = pd.concat([df.iloc[[0]], df.iloc[[81]], df_670])
df_670 = df_670.T
df_670.columns = df_670.loc['항목명1']
df_670 = df_670.drop(['항목명1', '항목명2'], axis=0)
df_670['경기_소비자_중앙값'] = (df_670['경기종합지수(동행지수순환변동치)'] + df_670['소비자심리지수']) / 2

for c in df_670.columns:
    df_670[c] = df_670[c].astype('float')

# %%
corr_670 = df_670.corrwith(df_670.경기_소비자_중앙값, method='pearson') 
corr_670 = pd.DataFrame(corr_670, columns=['상관계수']) 
corr_670 = corr_670.sort_values(by='상관계수')

# %%
plt.figure(figsize = (5, 5))
sns.heatmap(corr_670, annot=True, fmt='.2f', linewidths=.5, cmap='Reds')
plt.title('Heatmap')
plt.show()

# %% [markdown]
# ## 70세 이상

# %%
df_70 = df[df['항목명2'] == '70세이상']
df_70 = pd.concat([df.iloc[[0]], df.iloc[[81]], df_70])
df_70 = df_70.T
df_70.columns = df_70.loc['항목명1']
df_70 = df_70.drop(['항목명1', '항목명2'], axis=0)
df_70['경기_소비자_중앙값'] = (df_70['경기종합지수(동행지수순환변동치)'] + df_70['소비자심리지수']) / 2

for c in df_70.columns:
    df_70[c] = df_70[c].astype('float')

# %%
corr_70 = df_70.corrwith(df_70.경기_소비자_중앙값, method='pearson') 
corr_70 = pd.DataFrame(corr_70, columns=['상관계수']) 
corr_70 = corr_70.sort_values(by='상관계수')

# %%
plt.figure(figsize = (5, 5))
sns.heatmap(corr_70, annot=True, fmt='.2f', linewidths=.5, cmap='Reds')
plt.title('Heatmap')
plt.show()
