# %% [markdown]
# ### 실제 사이트 크롤링 - 신세계 인터넷 쇼핑몰

# %%
import bs4
import requests as rq
import pandas as pd
from selenium import webdriver

# %% [markdown]
# #### 사이트에 접속하고 탐색해 본다:

# %% [markdown]
# 1. 먼저 다음 사이트에 들어가서 살펴본다:  [신세계 건강식품](http://department.ssg.com/disp/category.ssg?dispCtgId=3500003739&page=1)
# 2. 크롬에서 3점 메뉴 버튼을 누르고 **도구 더보기** ==> **개발자 도구**를 선택해서 개발자 도구를 연다.
# 3. 개발자 도구 왼쪽 상단의 화살표 버튼을 눌러서 사이트 일부를 서택하고 해당 HTML코드를 볼 수 있다. "[CTRL] + [SHIFT] + C" 조합으로 대체할 수 있다.

# %%
# 웹드라이버 로딩.
my_driver = webdriver.Chrome('chromedriver.exe')

# %%
# 사이트에 접속.
my_url = "http://department.ssg.com/disp/category.ssg?dispCtgId=3500003739&page="
my_driver.get(my_url + str(1))

# %%
my_html = my_driver.page_source                      # 사이트 내용을 가져온다.
my_soup = bs4.BeautifulSoup(my_html, 'html.parser')     # BeautifulSoup 객체 반환. 'html.parser' 사용.

# %%
my_ul = my_soup.find('ul', class_='cunit_thmb_lst')                # 단 하나의 ul 태그.
type(my_ul)
# Out:
# bs4.element.Tag

# %%
# 이름만 가져와 본다.
my_names = my_ul.select('a em.tx_ko')
my_names_list =[x.text.strip() for x in my_names]
print(my_names_list)
# Out:
# ['(유통기한 2020.09.13 까지)[유한건강생활 뉴오리진] 이너플로라 60캡슐_2개월분_여성질유산균 프로바이오틱스', '화애락 진', '타히티골드 노니주스 원액 946ml x 2병 SET', '60일 벌크', '[센트룸] 포맨 + 포우먼 세트', '아이패스 J (11-13세)', '수퍼바이오틱스/60캡슐', '(유통기한 2020.09.11 까지)[유한건강생활 뉴오리진] 이너플로라 30캡슐_1개월분 여성질유산균 프로바이오틱스', '루테인+오메가3/60캡슐x2팩', '타히티골드 노니주스 원액 946ml', '셀큐브바이오 K크다 3개월 (9BOX) / ♥가격인하+사은품(기간한정)', '에버콜라겐코큐 CoQ 84정 x3개/에버콜라겐타임7포증정', '뉴케어 구수한맛 아셉틱 (200ml x 60팩)', '마이크로바이옴7 포맨 유산균 2통 (60일분)+추가 4일분', '알파프로젝트 눈건강 500mg*90캡슐 (30일분)', '셀큐브바이오 K크다 1개월 (3BOX) / ♥가격인하+사은품(기간한정)', '폴리코사놀10 (30정) X 3개 세트 + 바디원 비누 정품 증정!', '비타민D800 (60캡슐)', '트리플러스맨+우먼커플세트', '키즈어린이수퍼바이오틱스/30포x2팩', '트리플러스맨/90캡슐x2팩', '루테인', '프로폴리스 골드', '마이크로바이옴7 키즈 유산균 1통 (30일분)+추가 4일분', '오메가3 700 DHA/EPA (60캡슐/2개월)', '뉴케어 당플랜 아셉틱 (200ml x 60팩)', '하루 유산균 19 x 6ea', '셀큐브바이오 K크다 키즈 3개월 (9BOX) / ♥가격인하+사은품(기간한정)', '황진단 (12환)', '엽산 800 (100정) x 2병', '알파프로젝트 혈행건강 500mg*60캡슐 (30일분)', '[센트룸] 여성 멀티비타민 실버 포우먼 (50정) x 2통', '천녹톤(60포)', '키즈 츄어블 칼슘 / 72g(1,200mg X 60정)', '키즈어린이수퍼바이오틱스/30포', '칼슘+비타민D/60정x2팩', '원스데일리 멀티비타민 60정 (2개월분)', '루테인+오메가3/60캡슐x3팩', '비타민D 1000IU (90정/3개월)', '알파프로젝트 간건강 600mg*180정 (30일분)', '[나우푸드] 비오틴 5000 (480mg x 60캡슐)', '안심캡슐 눈에좋은 루테인 플러스 120캡슐(PTP)', '철분 25 (90캡슐) x 2병', '[동국제약] 크릴오일 세트(벨기에산 크릴오일X2세트)', '비타민B 콤플렉스 100 (50캡슐/1개월20일)', '수퍼바이오틱스/60캡슐x2팩', '프로폴리스Plus/60캡슐x2팩', '천녹강환  4g*10환', '[이너플로라 30*2EA 묶음세트]_[유한건강생활 뉴오리진] 이너플로라 30캡슐(1개월분)*2EA', '메가맨 50 PLUS (50대이상 남성종합) / 60정(내용량90g)', '노스쇼어  유기농 아사이베리(Acaiberry)주스 750ML', '[유한건강생활 뉴오리진] 전홍삼 키즈스틱 10ml x 30포 홍삼스틱', '메가맨 멀티비타민&미네랄(남성종합비타민)/90정(내용량144.90g)', '혈행건강 노르웨이 알티지오메가3 1100 2세트', '셀큐브바이오 케이밸런스 + K크다1개월(3BOX)/ ♥가격인하+사은품증정(기간한정)', '감마리놀렌산 달맞이꽃종자유1300 (NEW) / 95캡슐(123.5g)', '우먼스울트라메가 멀티비타민&미네랄(여성종합비타민)/ 90정(내용량175g)', '마이크로바이옴7 시니어 유산균 1통 (30일분)+추가 2일분', '여성을위한멀티비타민미네랄/60캡슐', '수퍼바이오틱스+철분/30캡슐x2팩', '에버콜라겐코큐 CoQ 84정 x2개', '츄어블 비타민 D3 1000IU (60츄어블정/2개월)', '효소력(力)(3g45포)', '뷰티콜라겐 15포 / 6box', '[센트룸] 실버 포맨 + 실버 포우먼 세트', '구연산칼슘 플러스 마그네슘 /160정', '오메가3울트라/50캡슐', '진심 흑마늘즙', '식물성 오메가-3 DHA 200 (50캡슐/17일)', '우먼스울트라메가 50 PLUS (50대이상 여성종합) / 60정(내용량93g)', '노스쇼어 유기농 아사이베리(Acaiberry)주스 750ML 2병 SET', '남극 크릴 오일 500 30캡슐 x3개', '남녀종합비타민 세트/GNC 메가맨(90정)+우먼스울트라메가(90정)', '지드림자색양파즙 100ml x 30포', '마이크로바이옴7 우먼 유산균 1통 (30일분)+추가 2일분', '[센트룸] 실버 포맨 + 실버 포우먼 세트 x 2통', '[센트룸] 여성 멀티비타민 실버 포우먼 (50정)', '폴리코사놀5 (30정) X 4개 세트 + 바디원 비누(100g) 정품 증정!', '알파프로젝트 장건강 500mg*60캡슐 (30일분)', '수퍼바이오틱스/60캡슐x3팩']

# %%
# 가격만 가져와 본다.
my_prices = my_ul.select('div.opt_price em.ssg_price')
my_prices_list =[x.text.strip() for x in my_prices]
print(my_prices_list)
# Out:
# ['85,000', '160,000', '98,000', '360,000', '54,000', '130,000', '70,740', '50,000', '52,920', '53,900', '315,000', '124,200', '90,000', '136,000', '34,200', '105,000', '182,250', '28,800', '66,150', '51,300', '66,150', '45,360', '31,860', '48,000', '32,130', '97,800', '51,300', '306,000', '240,000', '38,520', '22,500', '54,000', '480,000', '28,800', '25,650', '35,280', '30,000', '79,380', '24,480', '35,100', '15,000', '36,900', '43,110', '69,000', '34,470', '116,640', '44,100', '300,000', '100,000', '37,440', '49,000', '72,250', '64,800', '89,000', '150,500', '76,500', '64,800', '78,000', '32,400', '70,560', '82,800', '17,460', '55,000', '89,100', '54,000', '32,400', '30,240', '56,000', '56,880', '37,440', '98,000', '67,500', '129,600', '32,400', '68,000', '108,000', '27,000', '110,880', '35,100', '174,960']

# %% [markdown]
# #### 가격 가져오기:

# %%
# 반복적인 부분은 함수로 처리한다.
# select 메서드 사용.
def get_prices(my_soup):
    my_names = my_ul.select('a em.tx_ko')
    my_names_list =[x.text.strip() for x in my_names]
    my_prices = my_ul.select('div.opt_price em.ssg_price')
    my_prices_list =[x.text.strip() for x in my_prices]
    my_prices_list_final= [float(''.join(a_price.split(','))) for a_price in my_prices_list]
    return pd.DataFrame({'Product':my_names_list, 'Price':my_prices_list_final})

# %%
for i in range(1,20):
    my_driver.get(my_url + str(i))
    my_html = my_driver.page_source
    soup = bs4.BeautifulSoup(my_html, 'html.parser')     # BeautifulSoup 객체 반환. 'html.parser' 사용.
    if i == 1:
        df = get_prices(soup)
    else:
        df = pd.concat([df, get_prices(soup)],axis=0,ignore_index=True)

# %%
df.shape
# Out:
# (1520, 2)

# %%
df
# Out:
#                                                 Product     Price
# 0     (유통기한 2020.09.13 까지)[유한건강생활 뉴오리진] 이너플로라 60캡슐_2...   85000.0
# 1                                                 화애락 진  160000.0
# 2                          타히티골드 노니주스 원액 946ml x 2병 SET   98000.0
# 3                                                60일 벌크  360000.0
# 4                                     [센트룸] 포맨 + 포우먼 세트   54000.0
# 5                                       아이패스 J (11-13세)  130000.0
# 6                                          수퍼바이오틱스/60캡슐   70740.0
# 7     (유통기한 2020.09.11 까지)[유한건강생활 뉴오리진] 이너플로라 30캡슐_1...   50000.0
# 8                                      루테인+오메가3/60캡슐x2팩   52920.0
# 9                                   타히티골드 노니주스 원액 946ml   53900.0
# 10              셀큐브바이오 K크다 3개월 (9BOX) / ♥가격인하+사은품(기간한정)  315000.0
# 11                      에버콜라겐코큐 CoQ 84정 x3개/에버콜라겐타임7포증정  124200.0
# 12                           뉴케어 구수한맛 아셉틱 (200ml x 60팩)   90000.0
# 13                     마이크로바이옴7 포맨 유산균 2통 (60일분)+추가 4일분  136000.0
# 14                         알파프로젝트 눈건강 500mg*90캡슐 (30일분)   34200.0
# 15              셀큐브바이오 K크다 1개월 (3BOX) / ♥가격인하+사은품(기간한정)  105000.0
# 16                폴리코사놀10 (30정) X 3개 세트 + 바디원 비누 정품 증정!  182250.0
# 17                                       비타민D800 (60캡슐)   28800.0
# 18                                        트리플러스맨+우먼커플세트   66150.0
# 19                                  키즈어린이수퍼바이오틱스/30포x2팩   51300.0
# 20                                       트리플러스맨/90캡슐x2팩   66150.0
# 21                                                  루테인   45360.0
# 22                                             프로폴리스 골드   31860.0
# 23                     마이크로바이옴7 키즈 유산균 1통 (30일분)+추가 4일분   48000.0
# 24                          오메가3 700 DHA/EPA (60캡슐/2개월)   32130.0
# 25                            뉴케어 당플랜 아셉틱 (200ml x 60팩)   97800.0
# 26                                      하루 유산균 19 x 6ea   51300.0
# 27           셀큐브바이오 K크다 키즈 3개월 (9BOX) / ♥가격인하+사은품(기간한정)  306000.0
# 28                                            황진단 (12환)  240000.0
# 29                                   엽산 800 (100정) x 2병   38520.0
# ...                                                 ...       ...
# 1490                 노스쇼어  유기농 아사이베리(Acaiberry)주스 750ML   49000.0
# 1491             [유한건강생활 뉴오리진] 전홍삼 키즈스틱 10ml x 30포 홍삼스틱   72250.0
# 1492             메가맨 멀티비타민&미네랄(남성종합비타민)/90정(내용량144.90g)   64800.0
# 1493                         혈행건강 노르웨이 알티지오메가3 1100 2세트   89000.0
# 1494     셀큐브바이오 케이밸런스 + K크다1개월(3BOX)/ ♥가격인하+사은품증정(기간한정)  150500.0
# 1495            감마리놀렌산 달맞이꽃종자유1300 (NEW) / 95캡슐(123.5g)   76500.0
# 1496          우먼스울트라메가 멀티비타민&미네랄(여성종합비타민)/ 90정(내용량175g)   64800.0
# 1497                  마이크로바이옴7 시니어 유산균 1통 (30일분)+추가 2일분   78000.0
# 1498                                 여성을위한멀티비타민미네랄/60캡슐   32400.0
# 1499                                 수퍼바이오틱스+철분/30캡슐x2팩   70560.0
# 1500                                에버콜라겐코큐 CoQ 84정 x2개   82800.0
# 1501                     츄어블 비타민 D3 1000IU (60츄어블정/2개월)   17460.0
# 1502                                      효소력(力)(3g45포)   55000.0
# 1503                                   뷰티콜라겐 15포 / 6box   89100.0
# 1504                            [센트룸] 실버 포맨 + 실버 포우먼 세트   54000.0
# 1505                               구연산칼슘 플러스 마그네슘 /160정   32400.0
# 1506                                       오메가3울트라/50캡슐   30240.0
# 1507                                            진심 흑마늘즙   56000.0
# 1508                       식물성 오메가-3 DHA 200 (50캡슐/17일)   56880.0
# 1509        우먼스울트라메가 50 PLUS (50대이상 여성종합) / 60정(내용량93g)   37440.0
# 1510           노스쇼어 유기농 아사이베리(Acaiberry)주스 750ML 2병 SET   98000.0
# 1511                              남극 크릴 오일 500 30캡슐 x3개   67500.0
# 1512              남녀종합비타민 세트/GNC 메가맨(90정)+우먼스울트라메가(90정)  129600.0
# 1513                               지드림자색양파즙 100ml x 30포   32400.0
# 1514                   마이크로바이옴7 우먼 유산균 1통 (30일분)+추가 2일분   68000.0
# 1515                       [센트룸] 실버 포맨 + 실버 포우먼 세트 x 2통  108000.0
# 1516                        [센트룸] 여성 멀티비타민 실버 포우먼 (50정)   27000.0
# 1517         폴리코사놀5 (30정) X 4개 세트 + 바디원 비누(100g) 정품 증정!  110880.0
# 1518                       알파프로젝트 장건강 500mg*60캡슐 (30일분)   35100.0
# 1519                                    수퍼바이오틱스/60캡슐x3팩  174960.0
#
# [1520 rows x 2 columns]
